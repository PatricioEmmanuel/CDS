# %% [markdown]
# ***CODER HOUSE***
#
# **Data Science**
#
# **Patricio Emmanuel Dueñas**
#
# **Pre-Entrega**

# %% [markdown]
# -El data set sera formado usando la libreria de Python "LanusStasts" que recopila datos estadisticos de varios sitios web dedicados al Futbol.
#
# -La idea en principio es armar un mecanismo por el cual se pueda predecir que jugador es el mejor reemplazo en una posicion determinada a la hora de hacer incorporaciones en un determinado plantel.

# %%
#Se instala la libreria "LanusStats"

# %%
pip install --upgrade LanusStats
# Out:
# Collecting LanusStats
#   Downloading LanusStats-1.6.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from LanusStats) (2.1.4)
# Collecting mplsoccer (from LanusStats)
#   Downloading mplsoccer-1.4.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from LanusStats) (2.32.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from LanusStats) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from LanusStats) (1.26.4)
# Collecting bs4 (from LanusStats)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from LanusStats) (9.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->LanusStats) (4.12.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->LanusStats) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->LanusStats) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->LanusStats) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->LanusStats) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->LanusStats) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->LanusStats) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->LanusStats) (2.8.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mplsoccer->LanusStats) (1.13.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from mplsoccer->LanusStats) (0.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->LanusStats) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->LanusStats) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->LanusStats) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->LanusStats) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->LanusStats) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->LanusStats) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->LanusStats) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->LanusStats) (2.6)
# Downloading LanusStats-1.6.2-py3-none-any.whl (33 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading mplsoccer-1.4.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: bs4, mplsoccer, LanusStats
# Successfully installed LanusStats-1.6.2 bs4-0.0.2 mplsoccer-1.4.0

# %%
#Se importan las librerias que seran utilizadas
import pandas as pd
import numpy as np
import seaborn as sn
import LanusStats as ls

# %%
fbref = ls.Fbref()
ls.get_available_season_for_leagues ('Fbref', 'Primera Division Argentina')
# Out:
# {'id': 21,
#  'slug': 'Primera-Division',
#  'seasons': {'2021', '2022', '2023', '2024'}}

# %%
#En principio solo descubri como llamar a una liga a la vez nada mas pero la idea seria poder incorporar mas ligas para sumar mayor cantidad de datos

df= fbref.get_all_player_season_stats ('Primera Division Argentina','2021')
# Out:
# stats
# Starting to scrape player data from Fbref...
# keepers
# Starting to scrape player data from Fbref...
# keepersadv
# Starting to scrape player data from Fbref...
# shooting
# Starting to scrape player data from Fbref...
# passing
# Starting to scrape player data from Fbref...
# passing_types
# Starting to scrape player data from Fbref...
# gca
# Starting to scrape player data from Fbref...
# defense
# Starting to scrape player data from Fbref...
# possession
# Starting to scrape player data from Fbref...
# playingtime
# Starting to scrape player data from Fbref...
# misc
# Starting to scrape player data from Fbref...

# %%
df_players = df[0]

# %%
df_players.head(8)
# Out:
#              Player stats_Nation stats_Pos   stats_Squad  \
# 0    Gonzalo Abrego       ar ARG        MF    Godoy Cruz
# 1     Jonás Acevedo       ar ARG     MF,FW       Huracán
# 2     Lucas Acevedo       ar ARG        DF      Platense
# 3    Nelson Acevedo       ar ARG        MF    Godoy Cruz
# 4  Patricio Acevedo       ar ARG        DF   Newell's OB
# 5  Guillermo Acosta       ar ARG        MF  Atlé Tucumán
# 6    Lautaro Acosta       ar ARG        MF         Lanús
# 7      Lucas Acosta       ar ARG        GK         Lanús
#
#                    stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# 0  Primera Division Argentina        21       2000       21           18
# 1  Primera Division Argentina        23       1997       18           10
# 2  Primera Division Argentina        29       1991       11           10
# 3  Primera Division Argentina        32       1988       23           22
# 4  Primera Division Argentina        18       2002        1            1
# 5  Primera Division Argentina        32       1988       20           16
# 6  Primera Division Argentina        32       1988       19           18
# 7  Primera Division Argentina        25       1995       13           13
#
#   stats_Min  ... misc_Crs misc_Int misc_TklW misc_PKwon misc_PKcon misc_OG  \
# 0     1,497  ...       18       12         7          0          0       0
# 1       898  ...       87        6         3          0          0       0
# 2       911  ...        0       18        12          0          0       0
# 3     1,827  ...        2       27        35          0          0       0
# 4        61  ...        0        2         1          0          0       0
# 5     1,401  ...       31       17        11          0          0       0
# 6     1,347  ...       20       11        12          1          0       0
# 7     1,170  ...        0        2         0          0          0       1
#
#   misc_Recov misc_Won misc_Lost misc_Won%
# 0         99       32        29      52.5
# 1         46        6        15      28.6
# 2         57       30        21      58.8
# 3        217       16        14      53.3
# 4          3        2         0     100.0
# 5        131       18        24      42.9
# 6         76       34        39      46.6
# 7          4        5         0     100.0
#
# [8 rows x 238 columns]

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Columns: 238 entries, Player to misc_Won%
# dtypes: object(238)
# memory usage: 1.4+ MB

# %%
df_players.shape
# Out:
# (775, 238)

# %%
print (df_players)
# Out:
#                Player stats_Nation stats_Pos    stats_Squad  \
# 0      Gonzalo Abrego       ar ARG        MF     Godoy Cruz
# 1       Jonás Acevedo       ar ARG     MF,FW        Huracán
# 2       Lucas Acevedo       ar ARG        DF       Platense
# 3      Nelson Acevedo       ar ARG        MF     Godoy Cruz
# 4    Patricio Acevedo       ar ARG        DF    Newell's OB
# ..                ...          ...       ...            ...
# 770   Nadir Zeineddin       ar ARG        FW       Platense
# 771       Kevin Zenon       ar ARG     FW,MF          Unión
# 772    Bruno Zuculini       ar ARG     MF,DF    River Plate
# 773    Fernando Zuqui       ar ARG        MF    Estudiantes
# 774      Mauro Zurita       ar ARG        DF  Independiente
#
#                      stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# 0    Primera Division Argentina        21       2000       21           18
# 1    Primera Division Argentina        23       1997       18           10
# 2    Primera Division Argentina        29       1991       11           10
# 3    Primera Division Argentina        32       1988       23           22
# 4    Primera Division Argentina        18       2002        1            1
# ..                          ...       ...        ...      ...          ...
# 770  Primera Division Argentina        20       2000        2            0
# 771  Primera Division Argentina        19       2001       19           10
# 772  Primera Division Argentina        27       1993       20           14
# 773  Primera Division Argentina        29       1991       24           24
# 774  Primera Division Argentina        20       2000        2            1
#
#     stats_Min  ... misc_Crs misc_Int misc_TklW misc_PKwon misc_PKcon misc_OG  \
# 0       1,497  ...       18       12         7          0          0       0
# 1         898  ...       87        6         3          0          0       0
# 2         911  ...        0       18        12          0          0       0
# 3       1,827  ...        2       27        35          0          0       0
# 4          61  ...        0        2         1          0          0       0
# ..        ...  ...      ...      ...       ...        ...        ...     ...
# 770        19  ...        0        0         0          0          0       0
# 771       941  ...       69        6         5          0          0       0
# 772     1,247  ...        2       23        17          0          0       0
# 773     2,049  ...      154       34        30          0          0       0
# 774       107  ...        2        1         1          0          1       0
#
#     misc_Recov misc_Won misc_Lost misc_Won%
# 0           99       32        29      52.5
# 1           46        6        15      28.6
# 2           57       30        21      58.8
# 3          217       16        14      53.3
# 4            3        2         0     100.0
# ..         ...      ...       ...       ...
# 770          1        3         2      60.0
# 771         48        5        10      33.3
# 772         99       30        17      63.8
# 773        167        8        19      29.6
# 774          7        4         3      57.1
#
# [775 rows x 238 columns]

# %%
df_players.describe()
# Out:
#              Player stats_Nation stats_Pos   stats_Squad  \
# count           775          775       775           775
# unique          767           17        10            26
# top     Matías Sosa       ar ARG        DF  Boca Juniors
# freq              2          679       232            45
#
#                         stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# count                          775       775        775      775          775
# unique                           1        27         27       25           26
# top     Primera Division Argentina        21       2000        1            0
# freq                           775        79         78       61          108
#
#        stats_Min  ... misc_Crs misc_Int misc_TklW misc_PKwon misc_PKcon  \
# count        775  ...      775      775       775        775        775
# unique       592  ...       98       49        45          3          4
# top            1  ...        0        0         0          0          0
# freq          11  ...      201      141       128        730        710
#
#        misc_OG misc_Recov misc_Won misc_Lost misc_Won%
# count      775        775      775       775       775
# unique       3        159       74        69       272
# top          0          0        0         0         0
# freq       753         31       97        84        55
#
# [4 rows x 238 columns]

# %%
list(df_players.columns)
# Out:
# ['Player',
#  'stats_Nation',
#  'stats_Pos',
#  'stats_Squad',
#  'stats_Comp',
#  'stats_Age',
#  'stats_Born',
#  'stats_MP',
#  'stats_Starts',
#  'stats_Min',
#  'stats_90s',
#  'stats_Gls',
#  'stats_Ast',
#  'stats_G+A',
#  'stats_G-PK',
#  'stats_PK',
#  'stats_PKatt',
#  'stats_CrdY',
#  'stats_CrdR',
#  'stats_xG',
#  'stats_npxG',
#  'stats_xAG',
#  'stats_npxG+xAG',
#  'stats_PrgC',
#  'stats_PrgP',
#  'stats_PrgR',
#  'stats_Gls',
#  'stats_Ast',
#  'stats_G+A',
#  'stats_G-PK',
#  'stats_G+A-PK',
#  'stats_xG',
#  'stats_xAG',
#  'stats_xG+xAG',
#  'stats_npxG',
#  'stats_npxG+xAG',
#  'shooting_Nation',
#  'shooting_Pos',
#  'shooting_Squad',
#  'shooting_Comp',
#  'shooting_Age',
#  'shooting_Born',
#  'shooting_90s',
#  'shooting_Gls',
#  'shooting_Sh',
#  'shooting_SoT',
#  'shooting_SoT%',
#  'shooting_Sh/90',
#  'shooting_SoT/90',
#  'shooting_G/Sh',
#  'shooting_G/SoT',
#  'shooting_Dist',
#  'shooting_FK',
#  'shooting_PK',
#  'shooting_PKatt',
#  'shooting_xG',
#  'shooting_npxG',
#  'shooting_npxG/Sh',
#  'shooting_G-xG',
#  'shooting_np:G-xG',
#  'passing_Nation',
#  'passing_Pos',
#  'passing_Squad',
#  'passing_Comp',
#  'passing_Age',
#  'passing_Born',
#  'passing_90s',
#  'passing_Cmp',
#  'passing_Att',
#  'passing_Cmp%',
#  'passing_TotDist',
#  'passing_PrgDist',
#  'passing_Cmp',
#  'passing_Att',
#  'passing_Cmp%',
#  'passing_Cmp',
#  'passing_Att',
#  'passing_Cmp%',
#  'passing_Cmp',
#  'passing_Att',
#  'passing_Cmp%',
#  'passing_Ast',
#  'passing_xAG',
#  'passing_xA',
#  'passing_A-xAG',
#  'passing_KP',
#  'passing_1/3',
#  'passing_PPA',
#  'passing_CrsPA',
#  'passing_PrgP',
#  'passing_types_Nation',
#  'passing_types_Pos',
#  'passing_types_Squad',
#  'passing_types_Comp',
#  'passing_types_Age',
#  'passing_types_Born',
#  'passing_types_90s',
#  'passing_types_Att',
#  'passing_types_Live',
#  'passing_types_Dead',
#  'passing_types_FK',
#  'passing_types_TB',
#  'passing_types_Sw',
#  'passing_types_Crs',
#  'passing_types_TI',
#  'passing_types_CK',
#  'passing_types_In',
#  'passing_types_Out',
#  'passing_types_Str',
#  'passing_types_Cmp',
#  'passing_types_Off',
#  'passing_types_Blocks',
#  'gca_Nation',
#  'gca_Pos',
#  'gca_Squad',
#  'gca_Comp',
#  'gca_Age',
#  'gca_Born',
#  'gca_90s',
#  'gca_SCA',
#  'gca_SCA90',
#  'gca_PassLive',
#  'gca_PassDead',
#  'gca_TO',
#  'gca_Sh',
#  'gca_Fld',
#  'gca_Def',
#  'gca_GCA',
#  'gca_GCA90',
#  'gca_PassLive',
#  'gca_PassDead',
#  'gca_TO',
#  'gca_Sh',
#  'gca_Fld',
#  'gca_Def',
#  'defense_Nation',
#  'defense_Pos',
#  'defense_Squad',
#  'defense_Comp',
#  'defense_Age',
#  'defense_Born',
#  'defense_90s',
#  'defense_Tkl',
#  'defense_TklW',
#  'defense_Def 3rd',
#  'defense_Mid 3rd',
#  'defense_Att 3rd',
#  'defense_Tkl',
#  'defense_Att',
#  'defense_Tkl%',
#  'defense_Lost',
#  'defense_Blocks',
#  'defense_Sh',
#  'defense_Pass',
#  'defense_Int',
#  'defense_Tkl+Int',
#  'defense_Clr',
#  'defense_Err',
#  'possession_Nation',
#  'possession_Pos',
#  'possession_Squad',
#  'possession_Comp',
#  'possession_Age',
#  'possession_Born',
#  'possession_90s',
#  'possession_Touches',
#  'possession_Def Pen',
#  'possession_Def 3rd',
#  'possession_Mid 3rd',
#  'possession_Att 3rd',
#  'possession_Att Pen',
#  'possession_Live',
#  'possession_Att',
#  'possession_Succ',
#  'possession_Succ%',
#  'possession_Tkld',
#  'possession_Tkld%',
#  'possession_Carries',
#  'possession_TotDist',
#  'possession_PrgDist',
#  'possession_PrgC',
#  'possession_1/3',
#  'possession_CPA',
#  'possession_Mis',
#  'possession_Dis',
#  'possession_Rec',
#  'possession_PrgR',
#  'playingtime_Nation',
#  'playingtime_Pos',
#  'playingtime_Squad',
#  'playingtime_Comp',
#  'playingtime_Age',
#  'playingtime_Born',
#  'playingtime_MP',
#  'playingtime_Min',
#  'playingtime_Mn/MP',
#  'playingtime_Min%',
#  'playingtime_90s',
#  'playingtime_Starts',
#  'playingtime_Mn/Start',
#  'playingtime_Compl',
#  'playingtime_Subs',
#  'playingtime_Mn/Sub',
#  'playingtime_unSub',
#  'playingtime_PPM',
#  'playingtime_onG',
#  'playingtime_onGA',
#  'playingtime_+/-',
#  'playingtime_+/-90',
#  'playingtime_On-Off',
#  'playingtime_onxG',
#  'playingtime_onxGA',
#  'playingtime_xG+/-',
#  'playingtime_xG+/-90',
#  'playingtime_On-Off',
#  'misc_Nation',
#  'misc_Pos',
#  'misc_Squad',
#  'misc_Comp',
#  'misc_Age',
#  'misc_Born',
#  'misc_90s',
#  'misc_CrdY',
#  'misc_CrdR',
#  'misc_2CrdY',
#  'misc_Fls',
#  'misc_Fld',
#  'misc_Off',
#  'misc_Crs',
#  'misc_Int',
#  'misc_TklW',
#  'misc_PKwon',
#  'misc_PKcon',
#  'misc_OG',
#  'misc_Recov',
#  'misc_Won',
#  'misc_Lost',
#  'misc_Won%']

# %%
nun_missing = (df_players[['Player',
 'stats_Nation',
 'stats_Pos',
 'stats_Squad',
 'stats_Comp',
 'stats_Age',
 'stats_Born',
 'stats_MP',
 'stats_Starts',
 'stats_Min',
 'stats_90s',
 'stats_Gls',
 'stats_Ast',
 'stats_G+A',
 'stats_G-PK',
 'stats_PK',
 'stats_PKatt',
 'stats_CrdY',
 'stats_CrdR',
 'stats_xG',
 'stats_npxG',
 'stats_xAG',
 'stats_npxG+xAG',
 'stats_PrgC',
 'stats_PrgP',
 'stats_PrgR',
 'stats_Gls',
 'stats_Ast',
 'stats_G+A',
 'stats_G-PK',
 'stats_G+A-PK',
 'stats_xG',
 'stats_xAG',
 'stats_xG+xAG',
 'stats_npxG',
 'stats_npxG+xAG',
 'shooting_Nation',
 'shooting_Pos',
 'shooting_Squad',
 'shooting_Comp',
 'shooting_Age',
 'shooting_Born',
 'shooting_90s',
 'shooting_Gls',
 'shooting_Sh',
 'shooting_SoT',
 'shooting_SoT%',
 'shooting_Sh/90',
 'shooting_SoT/90',
 'shooting_G/Sh',
 'shooting_G/SoT',
 'shooting_Dist',
 'shooting_FK',
 'shooting_PK',
 'shooting_PKatt',
 'shooting_xG',
 'shooting_npxG',
 'shooting_npxG/Sh',
 'shooting_G-xG',
 'shooting_np:G-xG',
 'passing_Nation',
 'passing_Pos',
 'passing_Squad',
 'passing_Comp',
 'passing_Age',
 'passing_Born',
 'passing_90s',
 'passing_Cmp',
 'passing_Att',
 'passing_Cmp%',
 'passing_TotDist',
 'passing_PrgDist',
 'passing_Cmp',
 'passing_Att',
 'passing_Cmp%',
 'passing_Cmp',
 'passing_Att',
 'passing_Cmp%',
 'passing_Cmp',
 'passing_Att',
 'passing_Cmp%',
 'passing_Ast',
 'passing_xAG',
 'passing_xA',
 'passing_A-xAG',
 'passing_KP',
 'passing_1/3',
 'passing_PPA',
 'passing_CrsPA',
 'passing_PrgP',
 'passing_types_Nation',
 'passing_types_Pos',
 'passing_types_Squad',
 'passing_types_Comp',
 'passing_types_Age',
 'passing_types_Born',
 'passing_types_90s',
 'passing_types_Att',
 'passing_types_Live',
 'passing_types_Dead',
 'passing_types_FK',
 'passing_types_TB',
 'passing_types_Sw',
 'passing_types_Crs',
 'passing_types_TI',
 'passing_types_CK',
 'passing_types_In',
 'passing_types_Out',
 'passing_types_Str',
 'passing_types_Cmp',
 'passing_types_Off',
 'passing_types_Blocks',
 'gca_Nation',
 'gca_Pos',
 'gca_Squad',
 'gca_Comp',
 'gca_Age',
 'gca_Born',
 'gca_90s',
 'gca_SCA',
 'gca_SCA90',
 'gca_PassLive',
 'gca_PassDead',
 'gca_TO',
 'gca_Sh',
 'gca_Fld',
 'gca_Def',
 'gca_GCA',
 'gca_GCA90',
 'gca_PassLive',
 'gca_PassDead',
 'gca_TO',
 'gca_Sh',
 'gca_Fld',
 'gca_Def',
 'defense_Nation',
 'defense_Pos',
 'defense_Squad',
 'defense_Comp',
 'defense_Age',
 'defense_Born',
 'defense_90s',
 'defense_Tkl',
 'defense_TklW',
 'defense_Def 3rd',
 'defense_Mid 3rd',
 'defense_Att 3rd',
 'defense_Tkl',
 'defense_Att',
 'defense_Tkl%',
 'defense_Lost',
 'defense_Blocks',
 'defense_Sh',
 'defense_Pass',
 'defense_Int',
 'defense_Tkl+Int',
 'defense_Clr',
 'defense_Err',
 'possession_Nation',
 'possession_Pos',
 'possession_Squad',
 'possession_Comp',
 'possession_Age',
 'possession_Born',
 'possession_90s',
 'possession_Touches',
 'possession_Def Pen',
 'possession_Def 3rd',
 'possession_Mid 3rd',
 'possession_Att 3rd',
 'possession_Att Pen',
 'possession_Live',
 'possession_Att',
 'possession_Succ',
 'possession_Succ%',
 'possession_Tkld',
 'possession_Tkld%',
 'possession_Carries',
 'possession_TotDist',
 'possession_PrgDist',
 'possession_PrgC',
 'possession_1/3',
 'possession_CPA',
 'possession_Mis',
 'possession_Dis',
 'possession_Rec',
 'possession_PrgR',
 'playingtime_Nation',
 'playingtime_Pos',
 'playingtime_Squad',
 'playingtime_Comp',
 'playingtime_Age',
 'playingtime_Born',
 'playingtime_MP',
 'playingtime_Min',
 'playingtime_Mn/MP',
 'playingtime_Min%',
 'playingtime_90s',
 'playingtime_Starts',
 'playingtime_Mn/Start',
 'playingtime_Compl',
 'playingtime_Subs',
 'playingtime_Mn/Sub',
 'playingtime_unSub',
 'playingtime_PPM',
 'playingtime_onG',
 'playingtime_onGA',
 'playingtime_+/-',
 'playingtime_+/-90',
 'playingtime_On-Off',
 'playingtime_onxG',
 'playingtime_onxGA',
 'playingtime_xG+/-',
 'playingtime_xG+/-90',
 'playingtime_On-Off',
 'misc_Nation',
 'misc_Pos',
 'misc_Squad',
 'misc_Comp',
 'misc_Age',
 'misc_Born',
 'misc_90s',
 'misc_CrdY',
 'misc_CrdR',
 'misc_2CrdY',
 'misc_Fls',
 'misc_Fld',
 'misc_Off',
 'misc_Crs',
 'misc_Int',
 'misc_TklW',
 'misc_PKwon',
 'misc_PKcon',
 'misc_OG',
 'misc_Recov',
 'misc_Won',
 'misc_Lost',
 'misc_Won%']] == 0).sum()
print(nun_missing)
# Out:
# Player           0
# stats_Nation     4
# stats_Pos        0
# stats_Squad      0
# stats_Comp       0
#                 ..
# misc_OG          0
# misc_Recov       0
# misc_Won         0
# misc_Lost        0
# misc_Won%       55
# Length: 306, dtype: int64

# %%
print (df)
# Out:
# (               Player stats_Nation stats_Pos    stats_Squad  \
# 0      Gonzalo Abrego       ar ARG        MF     Godoy Cruz
# 1       Jonás Acevedo       ar ARG     MF,FW        Huracán
# 2       Lucas Acevedo       ar ARG        DF       Platense
# 3      Nelson Acevedo       ar ARG        MF     Godoy Cruz
# 4    Patricio Acevedo       ar ARG        DF    Newell's OB
# ..                ...          ...       ...            ...
# 770   Nadir Zeineddin       ar ARG        FW       Platense
# 771       Kevin Zenon       ar ARG     FW,MF          Unión
# 772    Bruno Zuculini       ar ARG     MF,DF    River Plate
# 773    Fernando Zuqui       ar ARG        MF    Estudiantes
# 774      Mauro Zurita       ar ARG        DF  Independiente
#
#                      stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# 0    Primera Division Argentina        21       2000       21           18
# 1    Primera Division Argentina        23       1997       18           10
# 2    Primera Division Argentina        29       1991       11           10
# 3    Primera Division Argentina        32       1988       23           22
# 4    Primera Division Argentina        18       2002        1            1
# ..                          ...       ...        ...      ...          ...
# 770  Primera Division Argentina        20       2000        2            0
# 771  Primera Division Argentina        19       2001       19           10
# 772  Primera Division Argentina        27       1993       20           14
# 773  Primera Division Argentina        29       1991       24           24
# 774  Primera Division Argentina        20       2000        2            1
#
#     stats_Min  ... misc_Crs misc_Int misc_TklW misc_PKwon misc_PKcon misc_OG  \
# 0       1,497  ...       18       12         7          0          0       0
# 1         898  ...       87        6         3          0          0       0
# 2         911  ...        0       18        12          0          0       0
# 3       1,827  ...        2       27        35          0          0       0
# 4          61  ...        0        2         1          0          0       0
# ..        ...  ...      ...      ...       ...        ...        ...     ...
# 770        19  ...        0        0         0          0          0       0
# 771       941  ...       69        6         5          0          0       0
# 772     1,247  ...        2       23        17          0          0       0
# 773     2,049  ...      154       34        30          0          0       0
# 774       107  ...        2        1         1          0          1       0
#
#     misc_Recov misc_Won misc_Lost misc_Won%
# 0           99       32        29      52.5
# 1           46        6        15      28.6
# 2           57       30        21      58.8
# 3          217       16        14      53.3
# 4            3        2         0     100.0
# ..         ...      ...       ...       ...
# 770          1        3         2      60.0
# 771         48        5        10      33.3
# 772         99       30        17      63.8
# 773        167        8        19      29.6
# 774          7        4         3      57.1
#
# [775 rows x 238 columns],                    Player keepers_Nation keepers_Pos     keepers_Squad  \
# 0            Lucas Acosta         ar ARG          GK             Lanús
# 1            Alan Aguerre         ar ARG          GK       Newell's OB
# 2      Facundo Altamirano         ar ARG          GK          Banfield
# 3         Mariano Andújar         ar ARG          GK       Estudiantes
# 4           Gabriel Arias         cl CHI          GK       Racing Club
# 5           Franco Armani         ar ARG          GK       River Plate
# 6         Enrique Bologna         ar ARG          GK       River Plate
# 7             Jorge Broun         ar ARG          GK   Rosario Central
# 8         Leonardo Burián         uy URU          GK             Colón
# 9        Facundo Cambeses         ar ARG          GK          Banfield
# 10           Lucas Chávez         ar ARG          GK       Arg Juniors
# 11         Ignacio Chicco         ar ARG          GK             Colón
# 12       Jorge De Olivera         ar ARG          GK          Platense
# 13          José Devecchi         ar ARG          GK          Aldosivi
# 14            Tomás Durso         ar ARG          GK       Gimnasia–LP
# 15          Juan Espínola         py PAR          GK        Godoy Cruz
# 16           Gastón Gómez         ar ARG          GK       Racing Club
# 17  Marcos Guillermo Díaz         ar ARG          GK           Huracán
# 18   Javier Hernán García         ar ARG          GK      Boca Juniors
# 19          Guido Herrera         ar ARG          GK          Talleres
# 20            Lucas Hoyos         ar ARG          GK   Vélez Sarsfield
# 21          Matías Ibáñez         ar ARG          GK         Patronato
# 22           Carlos Lampe         bo BOL          GK   Vélez Sarsfield
# 23    Federico Lanzillota         ar ARG          GK       Arg Juniors
# 24         Agustín Lastra         ar ARG          GK      Boca Juniors
# 25     Cristian Lucchetti         ar ARG          GK      Atlé Tucumán
# 26         Ramiro Macagno         ar ARG          GK       Newell's OB
# 27        Matías Mansilla         ar ARG          GK         Patronato
# 28       Alejandro Medina         ar ARG          GK           Arsenal
# 29         Andrés Mehring         ar ARG          GK  Cen. Córdoba–SdE
# 30        Lautaro Morales         ar ARG          GK             Lanús
# 31       Sebastián Moyano         ar ARG          GK             Unión
# 32             Luis Ojeda         ar ARG          GK          Platense
# 33        Roberto Ramírez         ar ARG          GK        Godoy Cruz
# 34            Rodrigo Rey         ar ARG          GK       Gimnasia–LP
# 35        César Rigamonti         ar ARG          GK  Cen. Córdoba–SdE
# 36            Juan Romero         ar ARG          GK   Rosario Central
# 37          Agustín Rossi         ar ARG          GK      Boca Juniors
# 38           Daniel Sappa         ar ARG          GK           Arsenal
# 39         Sebastián Sosa         uy URU          GK     Independiente
# 40          César Taborda         ar ARG          GK  Cen. Córdoba–SdE
# 41      Sebastián Torrico         ar ARG          GK       San Lorenzo
# 42        Ezequiel Unsain         ar ARG          GK    Defensa y Just
# 43       Manuel Vicentini         ar ARG          GK         Sarmiento
#
#                   keepers_Comp keepers_Age keepers_Born keepers_MP  \
# 0   Primera Division Argentina          25         1995         13
# 1   Primera Division Argentina          30         1990         17
# 2   Primera Division Argentina          24         1996         17
# 3   Primera Division Argentina          37         1983         25
# 4   Primera Division Argentina          33         1987         20
# 5   Primera Division Argentina          34         1986         21
# 6   Primera Division Argentina          38         1982          4
# 7   Primera Division Argentina          34         1986         18
# 8   Primera Division Argentina          37         1984         23
# 9   Primera Division Argentina          23         1997          8
# 10  Primera Division Argentina          25         1995         11
# 11  Primera Division Argentina          24         1996          2
# 12  Primera Division Argentina          38         1982         10
# 13  Primera Division Argentina          25         1995         25
# 14  Primera Division Argentina          21         1999          1
# 15  Primera Division Argentina          26         1994         23
# 16  Primera Division Argentina          24         1996          5
# 17  Primera Division Argentina          34         1986         25
# 18  Primera Division Argentina          34         1987          2
# 19  Primera Division Argentina          28         1992         25
# 20  Primera Division Argentina          31         1989         24
# 21  Primera Division Argentina          34         1986         23
# 22  Primera Division Argentina          33         1987          1
# 23  Primera Division Argentina          28         1992         15
# 24  Primera Division Argentina          20         2001          2
# 25  Primera Division Argentina          42         1978         25
# 26  Primera Division Argentina          23         1997          8
# 27  Primera Division Argentina          24         1996          2
# 28  Primera Division Argentina          33         1987         21
# 29  Primera Division Argentina          26         1994          5
# 30  Primera Division Argentina          21         1999         12
# 31  Primera Division Argentina          30         1990         25
# 32  Primera Division Argentina          30         1990         16
# 33  Primera Division Argentina          24         1996          2
# 34  Primera Division Argentina          29         1991         25
# 35  Primera Division Argentina          33         1987         18
# 36  Primera Division Argentina          22         1998          8
# 37  Primera Division Argentina          25         1995         21
# 38  Primera Division Argentina          25         1995          4
# 39  Primera Division Argentina          34         1986         25
# 40  Primera Division Argentina          37         1984          2
# 41  Primera Division Argentina          40         1980         25
# 42  Primera Division Argentina          25         1995         25
# 43  Primera Division Argentina          30         1990         25
#
#    keepers_Starts keepers_Min  ... keepersadv_AvgLen keepersadv_Att  \
# 0              13       1,170  ...              35.0            134
# 1              17       1,530  ...              37.7            152
# 2              17       1,530  ...              41.6            161
# 3              25       2,250  ...              40.3            200
# 4              20       1,800  ...              33.2            188
# 5              21       1,890  ...              31.4            150
# 6               4         360  ...              32.9             39
# 7              18       1,569  ...              35.4            160
# 8              23       2,070  ...              32.7            221
# 9               8         720  ...              33.9             61
# 10             11         938  ...              29.0             76
# 11              2         180  ...              37.9             21
# 12             10         847  ...              41.0             88
# 13             25       2,250  ...              35.8            235
# 14              0          27  ...              58.2              5
# 15             23       2,070  ...              39.7            189
# 16              5         450  ...              40.2             63
# 17             25       2,250  ...              35.9            197
# 18              2         180  ...              37.8             13
# 19             25       2,250  ...              35.2            198
# 20             24       2,160  ...              33.6            138
# 21             23       2,070  ...              48.1            210
# 22              1          90  ...              27.4              8
# 23             14       1,312  ...              31.3            111
# 24              2         180  ...              39.5              8
# 25             25       2,250  ...              40.2            237
# 26              8         720  ...              36.9             72
# 27              2         180  ...              45.8             22
# 28             21       1,890  ...              46.8            234
# 29              5         450  ...              50.6             32
# 30             12       1,080  ...              30.7            104
# 31             25       2,250  ...              38.8            212
# 32             15       1,400  ...              41.3            148
# 33              2         180  ...              37.1             15
# 34             25       2,223  ...              42.7            202
# 35             18       1,620  ...              36.1            155
# 36              7         681  ...              32.4             71
# 37             21       1,890  ...              33.6            159
# 38              4         360  ...              35.7             31
# 39             25       2,250  ...              31.0            243
# 40              2         180  ...              32.2             16
# 41             25       2,250  ...              40.4            273
# 42             25       2,250  ...              35.6            234
# 43             25       2,250  ...              40.8            233
#
#    keepersadv_Launch% keepersadv_AvgLen keepersadv_Opp keepersadv_Stp  \
# 0                66.4              50.6            228             12
# 1                74.3              52.5            267             11
# 2                60.9              46.4            231              8
# 3                65.0              46.4            346              8
# 4                38.8              34.1            295             16
# 5                48.7              42.4            245             22
# 6                38.5              35.5             58              3
# 7                39.4              37.9            270             14
# 8                37.6              36.0            329             18
# 9                44.3              40.7             79              2
# 10               43.4              37.2            110             11
# 11               81.0              51.4             55              2
# 12               70.5              49.6            151              9
# 13               66.8              46.4            431             17
# 14              100.0              62.2              8              0
# 15               54.5              46.4            291             33
# 16               41.3              38.1            115              5
# 17               40.1              35.6            369             22
# 18               46.2              38.6             30              0
# 19               27.8              30.8            355             18
# 20               54.3              42.7            345             13
# 21               88.1              57.9            402             22
# 22               25.0              32.0             23              3
# 23               35.1              33.8            173              7
# 24               87.5              57.9             23              1
# 25               70.9              54.1            334              7
# 26               55.6              47.1            143             13
# 27              100.0              64.1             33              3
# 28               87.2              61.6            334             19
# 29               87.5              60.9             79              3
# 30               54.8              42.9            184             19
# 31               76.9              54.9            360              7
# 32               70.3              47.9            269             15
# 33               20.0              29.5             26              0
# 34               60.4              45.9            436             25
# 35               58.7              46.6            278             11
# 36               45.1              37.2             93              1
# 37               54.1              40.9            242             16
# 38               64.5              49.1             61              2
# 39               33.7              31.0            371             15
# 40               75.0              52.9             28              0
# 41               73.6              49.3            351             11
# 42               46.6              37.4            504             24
# 43               60.9              44.2            425             25
#
#    keepersadv_Stp% keepersadv_#OPA keepersadv_#OPA/90 keepersadv_AvgDist
# 0              5.3               3               0.23                8.3
# 1              4.1               9               0.53               13.5
# 2              3.5               4               0.24               11.9
# 3              2.3              28               1.12               17.5
# 4              5.4               9               0.45               11.1
# 5              9.0              25               1.19               15.9
# 6              5.2               1               0.25               10.8
# 7              5.2              17               0.98               14.7
# 8              5.5              23               1.00               15.1
# 9              2.5               2               0.25               11.9
# 10            10.0               9               0.86               15.0
# 11             3.6               4               2.00               13.6
# 12             6.0               2               0.21                9.8
# 13             3.9              26               1.04               13.6
# 14             0.0               0               0.00                5.0
# 15            11.3              44               1.91               16.5
# 16             4.3               0               0.00                7.9
# 17             6.0              33               1.32               16.0
# 18             0.0               1               0.50               10.2
# 19             5.1              14               0.56               12.4
# 20             3.8              18               0.75               13.4
# 21             5.5              13               0.57               13.2
# 22            13.0               0               0.00               12.0
# 23             4.0              11               0.75               14.2
# 24             4.3               1               0.50               14.0
# 25             2.1              27               1.08               15.2
# 26             9.1               5               0.63               11.1
# 27             9.1               4               2.00               14.2
# 28             5.7               2               0.10                9.0
# 29             3.8               6               1.20               16.3
# 30            10.3               6               0.50               12.5
# 31             1.9              22               0.88               16.6
# 32             5.6               8               0.51               11.7
# 33             0.0               2               1.00               20.0
# 34             5.7              13               0.53               11.0
# 35             4.0               8               0.44               13.5
# 36             1.1               4               0.53               14.4
# 37             6.6              15               0.71               14.0
# 38             3.3               2               0.50               14.3
# 39             4.0              26               1.04               16.5
# 40             0.0               1               0.50               18.0
# 41             3.1              13               0.52               11.9
# 42             4.8              23               0.92               14.1
# 43             5.9              39               1.56               15.8
#
# [44 rows x 58 columns])

# %%
ls.visualizations.fbref_plot_player_percentiles('https://fbref.com/en/players/24377e64/Guillermo-Matias-Fernandez')
# Out:
# Gettings player percentiles...
# Starting to plot...

# %%
ls.get_available_leagues('Fbref')
# Out:
# ['Copa de la Liga',
#  'Primera Division Argentina',
#  'Primera Division Uruguay',
#  'Brasileirao',
#  'Brasileirao B',
#  'Primera Division Colombia',
#  'Primera Division Chile',
#  'Primera Division Peru',
#  'Primera Division Venezuela',
#  'Primera Division Ecuador',
#  'Primera Division Bolivia',
#  'Primera Division Paraguay',
#  'Brasileirao F',
#  'MLS',
#  'USL Championship',
#  'Premier League',
#  'La Liga',
#  'Ligue 1',
#  'Bundesliga',
#  'Serie A',
#  'Big 5 European Leagues',
#  'Danish Superliga',
#  'Eredivise',
#  'Primeira Liga Portugal',
#  'Copa America',
#  'Euros',
#  'Saudi League',
#  'EFL Championship',
#  'La Liga 2',
#  'Belgian Pro League',
#  'Challenger Pro League',
#  '2. Bundesliga',
#  'Ligue 2',
#  'Serie B',
#  'J1 League',
#  'NSWL',
#  'Wowens Super League',
#  'Liga F',
#  'Premier Division South Africa',
#  'Champions League',
#  'Europa League',
#  'Conference League',
#  'Copa Libertadores',
#  'Liga MX']

# %%
df1= fbref.get_all_player_season_stats ('Primera Division Chile','2021')
# Out:
# stats
# Starting to scrape player data from Fbref...
# keepers
# Starting to scrape player data from Fbref...
# keepersadv
# Starting to scrape player data from Fbref...
# shooting
# Starting to scrape player data from Fbref...
# passing
# Starting to scrape player data from Fbref...
# passing_types
# Starting to scrape player data from Fbref...
# gca
# Starting to scrape player data from Fbref...
# defense
# Starting to scrape player data from Fbref...
# possession
# Starting to scrape player data from Fbref...
# playingtime
# Starting to scrape player data from Fbref...
# misc
# Starting to scrape player data from Fbref...

# %%
df_players1= df1[0]

# %%
df_players1.head(8)
# Out:
#               Player stats_Nation stats_Pos     stats_Squad  \
# 0         Joe Abrigo       cl CHI        MF        Ñublense
# 1         Joe Abrigo       cl CHI        MF  Unión Española
# 2  Nicolás Abu Ghosh       ps PLE        FW       Palestino
# 3     Albert Acevedo       cl CHI        DF       O'Higgins
# 4      Diego Acevedo       cl CHI     MF,FW  Unión Española
# 5       Nicolás Aedo       cl CHI     MF,FW  Audax Italiano
# 6     Facundo Aguero       ar ARG        DF       La Serena
# 7       Eric Ahumada       cl CHI        DF     Antofagasta
#
#                stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# 0  Primera Division Chile        25       1995       13            6
# 1  Primera Division Chile        25       1995        6            1
# 2  Primera Division Chile        20       2000        8            2
# 3  Primera Division Chile        37       1983       17           14
# 4  Primera Division Chile        19       2001        9            7
# 5  Primera Division Chile        19       2001        7            5
# 6  Primera Division Chile        26       1995       25           23
# 7  Primera Division Chile        26       1994        8            5
#
#   stats_Min  ... misc_2CrdY misc_Fls misc_Fld misc_Off misc_Crs misc_Int  \
# 0       581  ...          0        6       24        1       23        4
# 1       162  ...          0        6       24        1       23        4
# 2       182  ...          0        2        4        2        3        0
# 3     1,062  ...          1        9        9        0        2       28
# 4       539  ...          0        4        4        0       16        8
# 5       321  ...          0        0        2        0       10        5
# 6     2,031  ...          0       22       14        1        0       50
# 7       497  ...          0        4        2        0        0        7
#
#   misc_TklW misc_PKwon misc_PKcon misc_OG
# 0         4        0.0        0.0       0
# 1         4        0.0        0.0       0
# 2         3        0.0        0.0       0
# 3        10        0.0        0.0       0
# 4         5        0.0        0.0       0
# 5         1        0.0        0.0       0
# 6        28        0.0        0.0       0
# 7        10        0.0        0.0       0
#
# [8 rows x 206 columns]

# %%
df_players1.shape
# Out:
# (543, 206)

# %%
ls.get_available_season_for_leagues('Fbref','Primera Division Colombia')
# Out:
# {'id': 41, 'slug': 'Primera-A', 'seasons': {'2021', '2022', '2023', '2024'}}

# %%
df2= fbref.get_all_player_season_stats ('Primera Division Colombia','2021')
# Out:
# stats
# Starting to scrape player data from Fbref...
# keepers
# Starting to scrape player data from Fbref...
# keepersadv
# Starting to scrape player data from Fbref...
# shooting
# Starting to scrape player data from Fbref...
# passing
# Starting to scrape player data from Fbref...
# passing_types
# Starting to scrape player data from Fbref...
# gca
# Starting to scrape player data from Fbref...
# defense
# Starting to scrape player data from Fbref...
# possession
# Starting to scrape player data from Fbref...
# playingtime
# Starting to scrape player data from Fbref...
# misc
# Starting to scrape player data from Fbref...

# %%
df_players2= df2[0]

# %%
df_players2.shape
# Out:
# (765, 206)

# %%
df_players2['stats_Min']
# Out:
# 0      2,837
# 1        270
# 2        107
# 3      2,230
# 4        583
#        ...
# 760    1,672
# 761    1,865
# 762      767
# 763    1,493
# 764      111
# Name: stats_Min, Length: 765, dtype: object

# %%
df_players = df_players.reset_index(drop=True)
df_players1 = df_players1.reset_index(drop=True)
df_players2 = df_players2.reset_index(drop=True)

# %%
print(df_players.index.duplicated().any())  # Verifica si hay duplicados
print(df_players1.index.duplicated().any())
print(df_players2.index.duplicated().any())
# Out:
# False
# False
# False

# %%
print("Indices de df_players:")
print(df_players.index)

print("Indices de df_players1:")
print(df_players1.index)

print("Indices de df_players2:")
print(df_players2.index)
# Out:
# Indices de df_players:
# RangeIndex(start=0, stop=775, step=1)
# Indices de df_players1:
# RangeIndex(start=775, stop=1318, step=1)
# Indices de df_players2:
# RangeIndex(start=1318, stop=2083, step=1)

# %%
dfx = pd.concat([df_players, df_players1, df_players2], ignore_index=True)
print(dfx)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-40-03dbfbee4a2d> in <cell line: 1>()
# ----> 1 dfx = pd.concat([df_players, df_players1, df_players2], ignore_index=True)
#       2 print(dfx)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     391     )
#     392
# --> 393     return op.get_result()
#     394
#     395
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     674                     obj_labels = obj.axes[1 - ax]
#     675                     if not new_labels.equals(obj_labels):
# --> 676                         indexers[ax] = obj_labels.get_indexer(new_labels)
#     677
#     678                 mgrs_indexers.append((obj._mgr, indexers))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3873
#    3874         if not self._index_as_unique:
# -> 3875             raise InvalidIndexError(self._requires_unique_msg)
#    3876
#    3877         if len(target) == 0:
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects
