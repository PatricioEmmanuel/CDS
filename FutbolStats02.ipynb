# %% [markdown]
# ***CODER HOUSE***
#
# **Data Science**
#
# **Patricio Emmanuel Dueñas**
#
# **Pre-Entrega**

# %% [markdown]
# -El data set sera formado usando la libreria de Python "LanusStasts" que recopila datos estadisticos de varios sitios web dedicados al Futbol.
#
# -La idea en principio es armar un mecanismo por el cual se pueda predecir que jugador es el mejor reemplazo en una posicion determinada a la hora de hacer incorporaciones en un determinado plantel.

# %% [markdown]
# ### Import Librarys

# %%
pip install --upgrade LanusStats

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import LanusStats as ls
import matplotlib.pyplot as plt

# %% [markdown]
# ###Import Data Sets

# %%
fbref = ls.Fbref()
ls.get_available_season_for_leagues ('Fbref', 'Primera Division Argentina')
# Out:
# {'id': 21,
#  'slug': 'Primera-Division',
#  'seasons': {'2021', '2022', '2023', '2024'}}

# %%
#En principio solo descubri como llamar a una liga a la vez nada mas pero la idea seria poder incorporar mas ligas para sumar mayor cantidad de datos

df= fbref.get_all_player_season_stats ('Primera Division Argentina','2021')
# Out:
# stats
# Starting to scrape player data from Fbref...
# keepers
# Starting to scrape player data from Fbref...
# keepersadv
# Starting to scrape player data from Fbref...
# shooting
# Starting to scrape player data from Fbref...
# passing
# Starting to scrape player data from Fbref...
# passing_types
# Starting to scrape player data from Fbref...
# gca
# Starting to scrape player data from Fbref...
# defense
# Starting to scrape player data from Fbref...
# possession
# Starting to scrape player data from Fbref...
# playingtime
# Starting to scrape player data from Fbref...
# misc
# Starting to scrape player data from Fbref...

# %%
df_players = df[0]

# %%
df_players.head(8)
# Out:
#              Player stats_Nation stats_Pos   stats_Squad  \
# 0    Gonzalo Abrego       ar ARG        MF    Godoy Cruz
# 1     Jonás Acevedo       ar ARG     MF,FW       Huracán
# 2     Lucas Acevedo       ar ARG        DF      Platense
# 3    Nelson Acevedo       ar ARG        MF    Godoy Cruz
# 4  Patricio Acevedo       ar ARG        DF   Newell's OB
# 5  Guillermo Acosta       ar ARG        MF  Atlé Tucumán
# 6    Lautaro Acosta       ar ARG        MF         Lanús
# 7      Lucas Acosta       ar ARG        GK         Lanús
#
#                    stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# 0  Primera Division Argentina        21       2000       21           18
# 1  Primera Division Argentina        23       1997       18           10
# 2  Primera Division Argentina        29       1991       11           10
# 3  Primera Division Argentina        32       1988       23           22
# 4  Primera Division Argentina        18       2002        1            1
# ...

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Columns: 238 entries, Player to misc_Won%
# dtypes: object(238)
# memory usage: 1.4+ MB

# %%
df_players.shape
# Out:
# (775, 238)

# %%
df_players.describe()
# Out:
#              Player stats_Nation stats_Pos   stats_Squad  \
# count           775          775       775           775
# unique          767           17        10            26
# top     Matías Sosa       ar ARG        DF  Boca Juniors
# freq              2          679       232            45
#
#                         stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# count                          775       775        775      775          775
# unique                           1        27         27       25           26
# top     Primera Division Argentina        21       2000        1            0
# freq                           775        79         78       61          108
#
#        stats_Min  ... misc_Crs misc_Int misc_TklW misc_PKwon misc_PKcon  \
# count        775  ...      775      775       775        775        775
# unique       592  ...       98       49        45          3          4
# ...

# %%
df_players.isna().sum()
# Out:
# Player          0
# stats_Nation    0
# stats_Pos       0
# stats_Squad     0
# stats_Comp      0
#                ..
# misc_OG         0
# misc_Recov      0
# misc_Won        0
# misc_Lost       0
# misc_Won%       0
# Length: 238, dtype: int64

# %%
ls.visualizations.fbref_plot_player_percentiles('https://fbref.com/en/players/24377e64/Guillermo-Matias-Fernandez')
# Out:
# Gettings player percentiles...
# Starting to plot...

# %%
ls.get_available_leagues('Fbref')
# Out:
# ['Copa de la Liga',
#  'Primera Division Argentina',
#  'Primera Division Uruguay',
#  'Brasileirao',
#  'Brasileirao B',
#  'Primera Division Colombia',
#  'Primera Division Chile',
#  'Primera Division Peru',
#  'Primera Division Venezuela',
#  'Primera Division Ecuador',
#  'Primera Division Bolivia',
#  'Primera Division Paraguay',
#  'Brasileirao F',
#  'MLS',
#  'USL Championship',
#  'Premier League',
#  'La Liga',
#  'Ligue 1',
#  'Bundesliga',
#  'Serie A',
#  'Big 5 European Leagues',
#  'Danish Superliga',
#  'Eredivise',
#  'Primeira Liga Portugal',
#  'Copa America',
#  'Euros',
#  'Saudi League',
#  'EFL Championship',
#  'La Liga 2',
#  'Belgian Pro League',
#  'Challenger Pro League',
#  '2. Bundesliga',
#  'Ligue 2',
#  'Serie B',
#  'J1 League',
#  'NSWL',
#  'Wowens Super League',
#  'Liga F',
#  'Premier Division South Africa',
#  'Champions League',
#  'Europa League',
#  'Conference League',
#  'Copa Libertadores',
#  'Liga MX']

# %%
df1= fbref.get_all_player_season_stats ('Primera Division Chile','2021')
# Out:
# stats
# Starting to scrape player data from Fbref...
# keepers
# Starting to scrape player data from Fbref...
# keepersadv
# Starting to scrape player data from Fbref...
# shooting
# Starting to scrape player data from Fbref...
# passing
# Starting to scrape player data from Fbref...
# passing_types
# Starting to scrape player data from Fbref...
# gca
# Starting to scrape player data from Fbref...
# defense
# Starting to scrape player data from Fbref...
# possession
# Starting to scrape player data from Fbref...
# playingtime
# Starting to scrape player data from Fbref...
# misc
# Starting to scrape player data from Fbref...

# %%
df_players1= df1[0]

# %%
df_players1.head(8)
# Out:
#               Player stats_Nation stats_Pos     stats_Squad  \
# 0         Joe Abrigo       cl CHI        MF        Ñublense
# 1         Joe Abrigo       cl CHI        MF  Unión Española
# 2  Nicolás Abu Ghosh       ps PLE        FW       Palestino
# 3     Albert Acevedo       cl CHI        DF       O'Higgins
# 4      Diego Acevedo       cl CHI     MF,FW  Unión Española
# 5       Nicolás Aedo       cl CHI     MF,FW  Audax Italiano
# 6     Facundo Aguero       ar ARG        DF       La Serena
# 7       Eric Ahumada       cl CHI        DF     Antofagasta
#
#                stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# 0  Primera Division Chile        25       1995       13            6
# 1  Primera Division Chile        25       1995        6            1
# 2  Primera Division Chile        20       2000        8            2
# 3  Primera Division Chile        37       1983       17           14
# 4  Primera Division Chile        19       2001        9            7
# ...

# %%
df_players1.shape
# Out:
# (543, 206)

# %%
ls.get_available_season_for_leagues('Fbref','Primera Division Colombia')
# Out:
# {'id': 41, 'slug': 'Primera-A', 'seasons': {'2021', '2022', '2023', '2024'}}

# %%
df2= fbref.get_all_player_season_stats ('Primera Division Colombia','2021')
# Out:
# stats
# Starting to scrape player data from Fbref...
# keepers
# Starting to scrape player data from Fbref...
# keepersadv
# Starting to scrape player data from Fbref...
# shooting
# Starting to scrape player data from Fbref...
# passing
# Starting to scrape player data from Fbref...
# passing_types
# Starting to scrape player data from Fbref...
# gca
# Starting to scrape player data from Fbref...
# defense
# Starting to scrape player data from Fbref...
# possession
# Starting to scrape player data from Fbref...
# playingtime
# Starting to scrape player data from Fbref...
# misc
# Starting to scrape player data from Fbref...

# %%
df_players2= df2[0]

# %%
df_players2.shape
# Out:
# (765, 206)

# %%
print("Indices de df_players:")
print(df_players.index)

print("Indices de df_players1:")
print(df_players1.index)

print("Indices de df_players2:")
print(df_players2.index)
# Out:
# Indices de df_players:
# RangeIndex(start=0, stop=775, step=1)
# Indices de df_players1:
# RangeIndex(start=0, stop=543, step=1)
# Indices de df_players2:
# RangeIndex(start=0, stop=765, step=1)

# %%
df3= fbref.get_all_player_season_stats ('Primera Division Uruguay','2021')
# Out:
# stats
# Starting to scrape player data from Fbref...
# keepers
# Starting to scrape player data from Fbref...
# keepersadv
# Starting to scrape player data from Fbref...
# shooting
# Starting to scrape player data from Fbref...
# passing
# Starting to scrape player data from Fbref...
# passing_types
# Starting to scrape player data from Fbref...
# gca
# Starting to scrape player data from Fbref...
# defense
# Starting to scrape player data from Fbref...
# possession
# Starting to scrape player data from Fbref...
# playingtime
# Starting to scrape player data from Fbref...
# misc
# Starting to scrape player data from Fbref...

# %%
df_players3= df3[0]

# %%
df_players3.shape
# Out:
# (516, 206)

# %%
df4= fbref.get_all_player_season_stats ('Primera Division Peru','2021')
# Out:
# stats
# Starting to scrape player data from Fbref...
# keepers
# Starting to scrape player data from Fbref...
# keepersadv
# Starting to scrape player data from Fbref...
# shooting
# Starting to scrape player data from Fbref...
# passing
# Starting to scrape player data from Fbref...
# passing_types
# Starting to scrape player data from Fbref...
# gca
# Starting to scrape player data from Fbref...
# defense
# Starting to scrape player data from Fbref...
# possession
# Starting to scrape player data from Fbref...
# playingtime
# Starting to scrape player data from Fbref...
# misc
# Starting to scrape player data from Fbref...

# %%
df_players4= df4[0]

# %%
df_players4.shape
# Out:
# (524, 206)

# %% [markdown]
# ##Uniendo los datos de diferentes ligas se forma el dataframe final.
# Este es uno alternativo porque quiero agregar la liga de Argentina pero no llegue a igualar el numero de columnas para concatenar correctamente.

# %%
dfx = pd.concat([df_players1, df_players2,df_players3,df_players4], ignore_index=True)
print(dfx)
# Out:
#                  Player stats_Nation stats_Pos     stats_Squad  \
# 0            Joe Abrigo       cl CHI        MF        Ñublense
# 1            Joe Abrigo       cl CHI        MF  Unión Española
# 2     Nicolás Abu Ghosh       ps PLE        FW       Palestino
# 3        Albert Acevedo       cl CHI        DF       O'Higgins
# 4         Diego Acevedo       cl CHI     MF,FW  Unión Española
# ...                 ...          ...       ...             ...
# 2343   Franco Zanelatto       pe PER        MF            USMP
# 2344        Adrián Zela       pe PER        DF      Binacional
# 2345        Héctor Zeta       pe PER        FW      Binacional
# 2346      José Zevallos       pe PER     DF,MF   Universitario
# 2347    Patrick Zubczuk       pe PER        GK   Universitario
#
#                   stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# 0     Primera Division Chile        25       1995       13            6
# ...

# %%
list(dfx.columns)
# Out:
# ['Player',
#  'stats_Nation',
#  'stats_Pos',
#  'stats_Squad',
#  'stats_Comp',
#  'stats_Age',
#  'stats_Born',
#  'stats_MP',
#  'stats_Starts',
#  'stats_Min',
#  'stats_90s',
#  'stats_Gls',
#  'stats_Ast',
#  'stats_G+A',
#  'stats_G-PK',
#  'stats_PK',
#  'stats_PKatt',
#  'stats_CrdY',
#  'stats_CrdR',
#  'stats_Gls',
#  'stats_Ast',
#  'stats_G+A',
#  'stats_G-PK',
#  'stats_G+A-PK',
#  'shooting_Nation',
#  'shooting_Pos',
#  'shooting_Squad',
#  'shooting_Comp',
#  'shooting_Age',
#  'shooting_Born',
#  'shooting_90s',
#  'shooting_Gls',
#  'shooting_Sh',
#  'shooting_SoT',
#  'shooting_SoT%',
#  'shooting_Sh/90',
#  'shooting_SoT/90',
#  'shooting_G/Sh',
#  'shooting_G/SoT',
#  'shooting_Dist',
#  'shooting_PK',
#  'shooting_PKatt',
#  'passing_Nation',
#  'passing_Pos',
#  'passing_Squad',
#  'passing_Comp',
#  'passing_Age',
#  'passing_Born',
#  'passing_90s',
#  'passing_Cmp',
#  'passing_Att',
#  'passing_Cmp%',
#  'passing_TotDist',
#  'passing_PrgDist',
# ...

# %% [markdown]
# ## A continuacion estan los graficos que por ahora estan nada pulidos y se ven bastante raros pero supongo que es por el gran numero de datos.
# La idea va a ser graficar con respecto a posiciones especificas lo que supongo va a resultar en graficos entendibles.
# Y aparte todavia no tuve tiempo de pensar bien y definir las relaciones que necesito buscar para obtener los datos necesario.

# %%
Mfig, ax = plt.subplots()
ax.scatter(data= dfx, x= 'Player', y= 'stats_Min')
ax.set_xlabel('Player')
ax.set_ylabel('stats_Min')
ax.set_title('MinxPlayer')
# Out:
# Text(0.5, 1.0, 'MinxPlayer')

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.hist(x= dfx['Player'], bins=None, density=False, orientation='vertical')
ax.set_xlabel('Players')

#Este grafico lo hice a ultimo momento y mas que nada para completar los parametros de la entrega.
# Out:
# Text(0.5, 0, 'Players')

# %%
print(dfx['stats_PK'].dtype) # Creo que no pude graficar el BoxPlot porque todos las columnas tienen dato en formato string y no me quedo tiempo para cambiar el formato.
# Out:
# object

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.boxplot(x=dfx['shooting_Age'])
ax.set_title('PlayerStats')
ax.set_xlabel('Player')
ax.set_ylabel('Pstats_Min')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-a4d920970b5f> in <cell line: 2>()
#       1 fig, ax = plt.subplots(figsize=(8, 4))
# ----> 2 ax.boxplot(x=dfx['shooting_Age'])
#       3 ax.set_title('PlayerStats')
#       4 ax.set_xlabel('Player')
#       5 ax.set_ylabel('Pstats_Min')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='stats_Min',x='Player',data=dfx)
# Out:
# <Axes: xlabel='Player', ylabel='stats_Min'>

# %%
sns.histplot(data=dfx, x='stats_Min',bins=20)
# Out:
# <Axes: xlabel='stats_Min', ylabel='Count'>

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
sns.scatterplot(x='Player', y= 'stats_Min',data=dfx)
plt.title('Relacion entre Players y Min')
plt.xlabel('Player')
plt.ylabel('Min')
# Out:
# Text(0, 0.5, 'Min')

# %% [markdown]
# ##Conclucion con respecto a los graficos claramente necesitan mucho trabajo pero llegue justo con el tiempo para al menos poder hacerlos funcionar.
